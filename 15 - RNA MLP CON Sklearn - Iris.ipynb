# %% [markdown]
# # Perceptron Multicapa (MLP)
#     Es uno de los tipos mas fundamentales
#     Consiste en multiples capas de neuronas conectadas entre sí
#     Se utiliza para tareas de clasificación y regresión
#     Funcionan con un flujo de informacion unidreccional (feedforward) desde la entrada hasta la salida

# %%
# Cargar modulos
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier

# %%
# Cargas datos
data = sns.load_dataset('iris')
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
train, test = train_test_split(data, test_size=0.4, stratify=data['species'], random_state=31)

# %%
X_train = train[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]
Y_train = train['species']
X_test = test[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]
Y_test = test['species']

# %%
# Crear el modelo
mlp = MLPClassifier(hidden_layer_sizes=(3,3), solver='sgd', learning_rate_init=0.01, max_iter=500)

# %%
data['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
# Codificar la variable de respuesta (categorica)
from sklearn.preprocessing import LabelEncoder
cofiicador = LabelEncoder()

# %%
data['species'] = cofiicador.fit_transform(data['species'])
species = pd.DataFrame({'species': ['setosa', 'versicolor', 'virginica']})
species
# Out:
#       species
# 0      setosa
# 1  versicolor
# 2   virginica

# %%
data.iloc[70:80]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width  species
# 70           5.9          3.2           4.8          1.8        1
# 71           6.1          2.8           4.0          1.3        1
# 72           6.3          2.5           4.9          1.5        1
# 73           6.1          2.8           4.7          1.2        1
# 74           6.4          2.9           4.3          1.3        1
# 75           6.6          3.0           4.4          1.4        1
# 76           6.8          2.8           4.8          1.4        1
# 77           6.7          3.0           5.0          1.7        1
# 78           6.0          2.9           4.5          1.5        1
# 79           5.7          2.6           3.5          1.0        1

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
noescalado = X_train.copy()
X_train_array = sc.fit_transform(X_train.values)

# %%
X_train = pd.DataFrame(X_train_array, index = X_train.index, columns = X_train.columns)

# %%
X_test_array = sc.fit_transform(X_test.values)
X_test = pd.DataFrame(X_test_array, index=X_test.index, columns=X_test.columns)
X_test
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 34      -1.079053     0.233762     -1.283389    -1.335061
# 48      -0.580069     1.636336     -1.283389    -1.335061
# 103      0.667391    -0.233762      1.053500     0.826252
# 92       0.043661    -0.935049      0.141543     0.015760
# 117      2.413836     1.870098      1.680470     1.366580
# 133      0.667391    -0.467525      0.768513     0.421006
# 56       0.667391     0.701287      0.540524     0.556088
# 90      -0.330577    -0.935049      0.369532     0.015760
# 51       0.792137     0.467525      0.426530     0.421006
# 119      0.293153    -1.870098      0.711516     0.421006
# 93      -0.954307    -1.636336     -0.257438    -0.254405
# 78       0.293153    -0.233762      0.426530     0.421006
# 130      2.039598    -0.467525      1.338486     0.961334
# 60      -0.954307    -2.337623     -0.143443    -0.254405
# 89      -0.330577    -1.168811      0.141543     0.150842
# 12      -1.203799     0.000000     -1.340386    -1.470143
# 53      -0.330577    -1.636336      0.141543     0.150842
# 20      -0.455323     0.935049     -1.169394    -1.335061
# 23      -0.829561     0.701287     -1.169394    -0.929815
# 105      2.289090     0.000000      1.623473     1.231498
# 148      0.542645     0.935049      0.939505     1.501662
# 28      -0.704815     0.935049     -1.340386    -1.335061
# 6       -1.453292     0.935049     -1.340386    -1.199979
# 26      -0.954307     0.935049     -1.226391    -1.064897
# 74       0.792137    -0.233762      0.312535     0.150842
# 98      -0.829561    -1.168811     -0.428430    -0.119322
# 88      -0.205831     0.000000      0.198541     0.150842
# 91       0.417899     0.000000      0.483527     0.285924
# 138      0.293153     0.000000      0.597521     0.826252
# 17      -0.829561     1.168811     -1.340386    -1.199979
# 55      -0.081085    -0.467525      0.426530     0.150842
# 16      -0.455323     2.103861     -1.397383    -1.064897
# 106     -1.079053    -1.168811      0.426530     0.691170
# 101      0.043661    -0.701287      0.768513     0.961334
# 114      0.043661    -0.467525      0.768513     1.636744
# 54       0.916884    -0.467525      0.483527     0.421006
# 49      -0.954307     0.701287     -1.340386    -1.335061
# 136      0.667391     0.935049      1.053500     1.636744
# 44      -0.829561     1.870098     -1.055400    -1.064897
# 10      -0.455323     1.636336     -1.283389    -1.335061
# 85       0.293153     0.935049      0.426530     0.556088
# 128      0.792137    -0.467525      1.053500     1.231498
# 134      0.417899    -0.935049      1.053500     0.285924
# 41      -1.578038    -1.636336     -1.397383    -1.199979
# 129      1.790106     0.000000      1.167494     0.556088
# 132      0.792137    -0.467525      1.053500     1.366580
# 139      1.415868     0.233762      0.939505     1.231498
# 45      -1.203799     0.000000     -1.340386    -1.199979
# 100      0.667391     0.701287      1.281489     1.771826
# 59      -0.704815    -0.701287      0.084546     0.285924
# 18      -0.081085     1.870098     -1.169394    -1.199979
# 66      -0.205831     0.000000      0.426530     0.421006
# 79      -0.081085    -0.935049     -0.143443    -0.254405
# 118      2.413836    -0.935049      1.794464     1.501662
# 38      -1.702784     0.000000     -1.397383    -1.335061
# 25      -0.954307     0.000000     -1.226391    -1.335061
# 39      -0.829561     0.935049     -1.283389    -1.335061
# 29      -1.328545     0.467525     -1.226391    -1.335061
# 111      0.792137    -0.701287      0.882508     0.961334
# 76       1.291122    -0.467525      0.597521     0.285924

# %%
mlp.fit(X_train, Y_train)
# Out:
# c:\Users\allan\OneDrive\Documents\Universidad\NOVENO CICLO\venv\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier(hidden_layer_sizes=(3, 3), learning_rate_init=0.01, max_iter=500,
#               solver='sgd')

# %%
mlp.coefs_
# Out:
# [array([[-0.29307783,  0.04785362, -0.02585688],
#         [ 0.34340927, -0.15415706,  0.52982031],
#         [-0.08036732,  0.45174812, -0.59043042],
#         [-0.85501126,  1.98356763, -0.51492881]]),
#  array([[-0.10357988, -0.94597085,  0.01633231],
#         [ 1.54540316, -1.17597486, -0.90355274],
#         [-0.90667173, -0.42160334, -0.13946334]]),
#  array([[-1.20033432,  0.61996836,  1.85773129],
#         [-0.92140902,  2.01600023, -1.49807555],
#         [-0.86986194, -0.17709988, -0.81964623]])]

# %%
from sklearn.metrics import accuracy_score

# %%
mlp.score(X_train, Y_train)
# Out:
# 0.9888888888888889

# %%
prediccion_train = mlp.predict(X_train)
prediccion_test = mlp.predict(X_test)

# %%
train_punteo = accuracy_score(prediccion_train, Y_train)
test_punteo = accuracy_score(prediccion_test, Y_test)

# %%
print('Puntaje de efectividad, grupo de entrenamiento: ', train_punteo *100)
print('Puntaje de efectividad, grupo de pruebas: ', test_punteo*100)
# Out:
# Puntaje de efectividad, grupo de entrenamiento:  98.88888888888889
# Puntaje de efectividad, grupo de pruebas:  93.33333333333333
